# %%
from sklearn import svm
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
X = [[19.1, 30], [57.4, 30], [79.1, 27.6], [87.8, 27], [90.4, 27.4], [95.7, 26.5], [97.8, 27.2]]
y = [0, 2.5, 5, 7.5, 10, 12.5, 15]
df = pd.DataFrame(X,columns=["humidity","temperature"])
df_ = pd.DataFrame(y,columns=["water"])
print(df)
print(df_)
X = df.iloc[:,1:2].values
y = df.iloc[:,1].values
# Out:
#    humidity  temperature
# 0      19.1         30.0
# 1      57.4         30.0
# 2      79.1         27.6
# 3      87.8         27.0
# 4      90.4         27.4
# 5      95.7         26.5
# 6      97.8         27.2
#    water
# 0    0.0
# 1    2.5
# 2    5.0
# 3    7.5
# 4   10.0
# 5   12.5
# 6   15.0

# %%
regr_soil = svm.SVR()
regr_soil.fit(X, y)
# Out:
# SVR()

# %%
index_minX = np.where(X == np.amin(X))
index_maxX = np.where(X == np.amax(X))
print(index_minX)
print(index_maxX)
X_grid = np.arange(min(X),max(X),0.01)
X_grid = X_grid.reshape(len(X_grid),1)
plt.scatter(X,y,color="blue")
plt.plot(X_grid, regr_soil.predict(X_grid), color="red")
plt.title("water needed")
plt.xlabel("{humidity,temperature}")
plt.ylabel("water")
ax = plt.gca()
ax.get_xaxis().set_visible(False)
plt.show()
# Out:
# (array([5], dtype=int32), array([0], dtype=int32))
# (array([0, 1], dtype=int32), array([0, 0], dtype=int32))
